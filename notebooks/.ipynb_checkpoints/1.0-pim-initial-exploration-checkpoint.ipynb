# %% [markdown]
# # Initial Exploration
#
# This project is based on the original [DeepPiCar](https://github.com/dctian/DeepPiCar) project which simply uses a Raspberry Pi with a camera on a simple radio controlled car. A vary similiar project [DeepPicar-v2](https://github.com/mbechtel2/DeepPicar-v2) done by members of University of Kansas. The DeepPiCar has data as well as the angles embedded in the images while DeepPicar-v2 has modulated the angles to $\lbrace -30, 0, +30\rbrace$ degrees on its outputs. Both are using the convolutional neural network architecture of the [DAVE-2](https://developer.nvidia.com/blog/deep-learning-self-driving-cars/) so for now training will only be done on the DeepPiCar data and comparison with their model.
#
# ## Camera Inputs
#
# This section will look at the images being supplied by the DeepPiCar project as well as some image distortions achievable. First thing is to import the required libraries.

# %%
from cv2 import cv2              # an open computer vision module
import glob                      # Regix searching of files
import imageio                   # loading images in numpy array
import matplotlib.pyplot as plt  # Plotting
# %matplotlib notebook
import numpy as np               # Array/Tensors
import os                        # finding paths
import pandas as pd              # Dataframe for viewing
import PIL                       # Python Imaging Library
import sys                       # manipulating the path variable
import tensorflow as tf          # Neural Networks

# %% [markdown]
# With these modules imported add in the location of the training images as well as the location of the DeepPiCar neural network.

# %%
sys.path.append(os.path.abspath('../data/external/'))
sys.path.append(os.path.abspath('../models/'))

# %% [markdown]
# With the added locations we can look load the data into a numpy data frame as well as a numpy array of angles.

# %%
# See number of images
image_list = glob.glob("../data/external/DeepPicar-data/*.png")  # All images

N = len(image_list)

image_vec = None  # Input
index_vec = np.empty((N,), dtype=np.int32) # Index
angle_vec = np.empty((N,), dtype=np.float64)  # Output Target

for i, f in enumerate(image_list):
    # Read in file
    image = imageio.imread(f)
    index = int(f.split('_')[-2])  # Frame index
    angle = float(f.split('_')[-1].split('.')[0])  # in degrees
    
    # Create image storage if necessary
    if image_vec is None:
        image_vec = np.empty((N,) + image.shape, dtype=np.float64)
    
    # Store file information
    image_vec[i] = image
    index_vec[i] = index
    angle_vec[i] = angle
    
    del image
    
# Some constants for resizing
target_img_height = 66
target_img_width = 200

# Resize the images
print("Original image vector dimensions: %s" % str(image_vec.shape))

image_vec = tf.image.resize(  # Maybe replace in network with crop
    images=tf.convert_to_tensor(image_vec),
    size=[target_img_height, target_img_width]
).numpy()

print("New image vector dimensions: %s" % str(image_vec.shape))

print("Minimum angle: %.0f degrees" % np.min(angle_vec))
print("Maximum angle: %.0f degrees" % np.max(angle_vec))
# Out:
# Original image vector dimensions: (219, 240, 320, 3)
# New image vector dimensions: (219, 66, 200, 3)
# Minimum angle: 44 degrees
# Maximum angle: 103 degrees

# %% [markdown]
# ## Model Building
#
# With the images loaded and reshaped to the DAVE-2 image size we create a DAVE-2 neural network model for initial comparison work.

# %%
def create_dave(input_shape):
    # Create tensorflow object
    dave_2_model = tf.keras.Sequential()

    # First is a normalization layer in DAVE-2 but I don't see it in DeepPicar-v2 model-5conv_3fc
    # Attempting to normalize over color
    dave_2_model.add(tf.keras.layers.LayerNormalization(
        axis=[1, 2, 3], trainable=False,
        input_shape=input_shape  # Specify ahead of time for compilation
    ))

    """
    Brief comment:
    * Both DeepPicar and DeepPicar-v2 use a 240x320 frame initially but DeepPicar-v2 reshapes=66x200
    * DAVE-2 uses 66x200
    * Either I need to downsample both or I just ignore it since the DeepPicar's match.
    * Going with matching. <- scratch, will match dimensions
    """

    # Second portion is the sequential 5x5 convolutions of increasing filters at 2x2 strides
    for i in range(3):
        dave_2_model.add(tf.keras.layers.Conv2D(
            filters=(24 + i*12),
            kernel_size=(5,5),
            strides=(2,2),
            padding='valid',
            data_format='channels_last',
            activation=tf.nn.relu
        ))

    # Third there is another grouping of Conv2D layers but a 3x3 kernel with no stride
    for i in range(2):
        dave_2_model.add(tf.keras.layers.Conv2D(
            filters=64,
            kernel_size=(3,3),
            padding='valid',
            data_format='channels_last',
            activation=tf.nn.relu
        ))

    # Fourth and final part is a flattening and then reduction to a single output
    dave_2_model.add(tf.keras.layers.Flatten())
    for n_neurons in [100, 50, 10, 1]:
        dave_2_model.add(tf.keras.layers.Dense(
            units=n_neurons,
            activation=(tf.nn.tanh if n_neurons == 1 else tf.nn.relu)
        ))

    # Compiling the model to see the initial structure
    dave_2_model.compile(
        optimizer='adam',
        loss=['mse'],
        metrics=['mse']
    )
    
    return dave_2_model

dave_2_model = create_dave(image_vec.shape[1:])
dave_2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_normalization (LayerNo (None, 66, 200, 3)        79200
# _________________________________________________________________
# conv2d (Conv2D)              (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               115300
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 331,419
# Trainable params: 252,219
# Non-trainable params: 79,200
# _________________________________________________________________

# %% [markdown]
# ## Model Training on DeepPicar
#
# With the model compiled and built initially, we will train on the DeepPicar Dataset and then see the accuraccy against the DeepPicar-v2 dataset

# %%
angle_center = 90.
angle_half_span = 30.

y_fit = (angle_vec - angle_center)/angle_half_span  # 30.  # 

# ensure -1 to 1 bounds
y_fit[y_fit < -1] = -1
y_fit[y_fit > 1] = 1

x_fit = image_vec

training_history = dave_2_model.fit(
    x=x_fit, y=y_fit,
    verbose=1,
    epochs=100,
    validation_split=0.2,
)
# Out:
# Train on 175 samples, validate on 44 samples
# Epoch 1/100
# 175/175 [==============================] - 3s 16ms/sample - loss: 0.1858 - mse: 0.1858 - val_loss: 0.0268 - val_mse: 0.0268
# Epoch 2/100
# 175/175 [==============================] - 0s 912us/sample - loss: 0.0881 - mse: 0.0881 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 3/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0570 - mse: 0.0570 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 4/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0465 - mse: 0.0465 - val_loss: 0.0213 - val_mse: 0.0213
# Epoch 5/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0372 - mse: 0.0372 - val_loss: 0.0254 - val_mse: 0.0254
# Epoch 6/100
# 175/175 [==============================] - 0s 916us/sample - loss: 0.0324 - mse: 0.0324 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 7/100
# 175/175 [==============================] - 0s 916us/sample - loss: 0.0220 - mse: 0.0220 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 8/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0204 - mse: 0.0204 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 9/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 10/100
# 175/175 [==============================] - 0s 905us/sample - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 11/100
# 175/175 [==============================] - 0s 898us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0163 - val_mse: 0.0163
# Epoch 12/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 13/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0316 - val_mse: 0.0316
# Epoch 14/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 15/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0065 - mse: 0.0065 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 16/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 17/100
# 175/175 [==============================] - 0s 910us/sample - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 18/100
# 175/175 [==============================] - 0s 915us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0157 - val_mse: 0.0157
# Epoch 19/100
# 175/175 [==============================] - 0s 920us/sample - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 20/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0220 - val_mse: 0.0220
# Epoch 21/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 22/100
# 175/175 [==============================] - 0s 950us/sample - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 23/100
# 175/175 [==============================] - 0s 910us/sample - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 24/100
# 175/175 [==============================] - 0s 883us/sample - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 25/100
# 175/175 [==============================] - 0s 885us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 26/100
# 175/175 [==============================] - 0s 931us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 27/100
# 175/175 [==============================] - 0s 900us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0218 - val_mse: 0.0218
# Epoch 28/100
# 175/175 [==============================] - 0s 912us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 29/100
# 175/175 [==============================] - 0s 901us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 30/100
# 175/175 [==============================] - 0s 900us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 31/100
# 175/175 [==============================] - 0s 894us/sample - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 32/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0269 - val_mse: 0.0269
# Epoch 33/100
# 175/175 [==============================] - 0s 894us/sample - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 34/100
# 175/175 [==============================] - 0s 898us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 35/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 36/100
# 175/175 [==============================] - 0s 889us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 37/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 38/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 39/100
# 175/175 [==============================] - 0s 888us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 40/100
# 175/175 [==============================] - 0s 891us/sample - loss: 8.5422e-04 - mse: 8.5422e-04 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 41/100
# 175/175 [==============================] - 0s 904us/sample - loss: 9.4024e-04 - mse: 9.4024e-04 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 42/100
# 175/175 [==============================] - 0s 909us/sample - loss: 9.5229e-04 - mse: 9.5229e-04 - val_loss: 0.0210 - val_mse: 0.0210
# Epoch 43/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 44/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 45/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0291 - val_mse: 0.0291
# Epoch 46/100
# 175/175 [==============================] - 0s 892us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 47/100
# 175/175 [==============================] - 0s 888us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 48/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 49/100
# 175/175 [==============================] - 0s 882us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 50/100
# 175/175 [==============================] - 0s 900us/sample - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0287 - val_mse: 0.0287
# Epoch 51/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 52/100
# 175/175 [==============================] - 0s 893us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0264 - val_mse: 0.0264
# Epoch 53/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 54/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 55/100
# 175/175 [==============================] - 0s 891us/sample - loss: 9.7037e-04 - mse: 9.7037e-04 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 56/100
# 175/175 [==============================] - 0s 890us/sample - loss: 8.0745e-04 - mse: 8.0745e-04 - val_loss: 0.0222 - val_mse: 0.0222
# Epoch 57/100
# 175/175 [==============================] - 0s 883us/sample - loss: 5.7205e-04 - mse: 5.7205e-04 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 58/100
# 175/175 [==============================] - 0s 890us/sample - loss: 5.3194e-04 - mse: 5.3194e-04 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 59/100
# 175/175 [==============================] - 0s 883us/sample - loss: 4.0704e-04 - mse: 4.0704e-04 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 60/100
# 175/175 [==============================] - 0s 891us/sample - loss: 3.7561e-04 - mse: 3.7561e-04 - val_loss: 0.0222 - val_mse: 0.0222
# Epoch 61/100
# 175/175 [==============================] - 0s 891us/sample - loss: 4.0407e-04 - mse: 4.0407e-04 - val_loss: 0.0225 - val_mse: 0.0225
# Epoch 62/100
# 175/175 [==============================] - 0s 897us/sample - loss: 3.0277e-04 - mse: 3.0277e-04 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 63/100
# 175/175 [==============================] - 0s 894us/sample - loss: 2.7213e-04 - mse: 2.7213e-04 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 64/100
# 175/175 [==============================] - 0s 906us/sample - loss: 2.0138e-04 - mse: 2.0138e-04 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 65/100
# 175/175 [==============================] - 0s 897us/sample - loss: 1.9532e-04 - mse: 1.9532e-04 - val_loss: 0.0222 - val_mse: 0.0222
# Epoch 66/100
# 175/175 [==============================] - 0s 901us/sample - loss: 1.6038e-04 - mse: 1.6038e-04 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 67/100
# 175/175 [==============================] - 0s 899us/sample - loss: 1.4725e-04 - mse: 1.4725e-04 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 68/100
# 175/175 [==============================] - 0s 889us/sample - loss: 1.8306e-04 - mse: 1.8306e-04 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 69/100
# 175/175 [==============================] - 0s 885us/sample - loss: 1.4204e-04 - mse: 1.4204e-04 - val_loss: 0.0246 - val_mse: 0.0246
# Epoch 70/100
# 175/175 [==============================] - 0s 880us/sample - loss: 1.4692e-04 - mse: 1.4692e-04 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 71/100
# 175/175 [==============================] - 0s 897us/sample - loss: 1.5181e-04 - mse: 1.5181e-04 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 72/100
# 175/175 [==============================] - 0s 902us/sample - loss: 1.8125e-04 - mse: 1.8125e-04 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 73/100
# 175/175 [==============================] - 0s 911us/sample - loss: 1.8844e-04 - mse: 1.8844e-04 - val_loss: 0.0230 - val_mse: 0.0230
# Epoch 74/100
# 175/175 [==============================] - 0s 900us/sample - loss: 1.6095e-04 - mse: 1.6095e-04 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 75/100
# 175/175 [==============================] - 0s 910us/sample - loss: 2.0226e-04 - mse: 2.0226e-04 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 76/100
# 175/175 [==============================] - 0s 891us/sample - loss: 2.2623e-04 - mse: 2.2623e-04 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 77/100
# 175/175 [==============================] - 0s 907us/sample - loss: 1.8630e-04 - mse: 1.8630e-04 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 78/100
# 175/175 [==============================] - 0s 896us/sample - loss: 1.6298e-04 - mse: 1.6298e-04 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 79/100
# 175/175 [==============================] - 0s 900us/sample - loss: 1.8631e-04 - mse: 1.8631e-04 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 80/100
# 175/175 [==============================] - 0s 902us/sample - loss: 2.4710e-04 - mse: 2.4710e-04 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 81/100
# 175/175 [==============================] - 0s 897us/sample - loss: 2.0668e-04 - mse: 2.0668e-04 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 82/100
# 175/175 [==============================] - 0s 891us/sample - loss: 2.3862e-04 - mse: 2.3862e-04 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 83/100
# 175/175 [==============================] - 0s 891us/sample - loss: 2.7967e-04 - mse: 2.7967e-04 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 84/100
# 175/175 [==============================] - 0s 896us/sample - loss: 2.0886e-04 - mse: 2.0886e-04 - val_loss: 0.0245 - val_mse: 0.0245
# Epoch 85/100
# 175/175 [==============================] - 0s 892us/sample - loss: 1.5586e-04 - mse: 1.5586e-04 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 86/100
# 175/175 [==============================] - 0s 912us/sample - loss: 1.8579e-04 - mse: 1.8579e-04 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 87/100
# 175/175 [==============================] - 0s 885us/sample - loss: 1.3680e-04 - mse: 1.3680e-04 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 88/100
# 175/175 [==============================] - 0s 886us/sample - loss: 1.2012e-04 - mse: 1.2012e-04 - val_loss: 0.0233 - val_mse: 0.0233
# Epoch 89/100
# 175/175 [==============================] - 0s 885us/sample - loss: 1.2938e-04 - mse: 1.2938e-04 - val_loss: 0.0242 - val_mse: 0.0242
# Epoch 90/100
# 175/175 [==============================] - 0s 897us/sample - loss: 7.2626e-05 - mse: 7.2626e-05 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 91/100
# 175/175 [==============================] - 0s 894us/sample - loss: 6.8893e-05 - mse: 6.8893e-05 - val_loss: 0.0230 - val_mse: 0.0230
# Epoch 92/100
# 175/175 [==============================] - 0s 902us/sample - loss: 6.5486e-05 - mse: 6.5486e-05 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 93/100
# 175/175 [==============================] - 0s 887us/sample - loss: 7.2129e-05 - mse: 7.2129e-05 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 94/100
# 175/175 [==============================] - 0s 889us/sample - loss: 8.5469e-05 - mse: 8.5469e-05 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 95/100
# 175/175 [==============================] - 0s 895us/sample - loss: 7.4557e-05 - mse: 7.4557e-05 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 96/100
# 175/175 [==============================] - 0s 889us/sample - loss: 7.6534e-05 - mse: 7.6534e-05 - val_loss: 0.0255 - val_mse: 0.0255
# Epoch 97/100
# 175/175 [==============================] - 0s 891us/sample - loss: 1.9089e-04 - mse: 1.9089e-04 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 98/100
# 175/175 [==============================] - 0s 907us/sample - loss: 1.8005e-04 - mse: 1.8005e-04 - val_loss: 0.0295 - val_mse: 0.0295
# Epoch 99/100
# 175/175 [==============================] - 0s 895us/sample - loss: 2.1649e-04 - mse: 2.1649e-04 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 100/100
# 175/175 [==============================] - 0s 869us/sample - loss: 1.8875e-04 - mse: 1.8875e-04 - val_loss: 0.0235 - val_mse: 0.0235

# %% [markdown]
# Before moving on, let us address training speeds. Another student working on iterations of DeepPicar-vx has been training using `Tensorflow v1`. They train using a batch size of 128 images and at 24 steps per epoch and consistently get 2 to 3 seconds per step i.e. over 128 images. This means at fastest 15,625 microseconds per sample while the compiled version in this notebook is achieving 858 microseconds per sample so there is about a 2 to 3 times speedup using a fairly average laptop but compiled tensorflow as opposed to a GoogleColab but noncompiled version. After the training we do some plotting to see the training history results.

# %%
loss_vec = np.array(training_history.history['loss'])
val_loss_vec = np.array(training_history.history['val_loss'])

epoch_vec = np.arange(loss_vec.shape[0]) + 1

fig, ax = plt.subplots(1, 1)

ax.plot(epoch_vec, loss_vec, color='C0', label="Training Loss")
ax.plot(epoch_vec, val_loss_vec, color='C1', label="Validation Loss")

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)

ax.set_xlabel("Training Epoch")
ax.set_ylabel("Mean Square Error")

ax.legend()

plt.show()
# Out:
# <div id='c2706fb6-b22b-42c8-9942-3238766cbe15'></div>

# %% [markdown]
# The training looks fine, maybe optimal epoch number is 50 epochs. Let us check visually to make sure the results look reasonable.

# %%
# Constant
frame_num = 130

x_base = 100
y_base = 60
radius = 20

p_angle = (angle_half_span*dave_2_model.predict(image_vec)[frame_num] + angle_center)/180*np.pi
t_angle = angle_vec[frame_num]/180*np.pi

fig, ax = plt.subplots(1, 1)

ax.imshow(image_vec[frame_num].astype(int))
ax.plot(  # Arrow might be better
    np.array([x_base, x_base + radius*np.cos(np.pi - p_angle)]),
    np.array([y_base, y_base - radius*np.sin(p_angle)]),
    linewidth=5,
    label=("Predicted Angle (%.1f)" % (180./np.pi*p_angle))
)

ax.plot(  # Arrow might be better
    np.array([x_base, x_base + radius*np.cos(np.pi - t_angle)]),
    np.array([y_base, y_base - radius*np.sin(t_angle)]),
    linewidth=5,
    color='C3',
    label=("Target Angle (%.1f)" % (180./np.pi*t_angle))
)

ax.set_title("Frame %i" % frame_num)
ax.set_xlabel("Pixel Width")
ax.set_ylabel("Pixel Height")
ax.legend()

plt.show()
# Out:
# <div id='a86f7953-b187-4357-9992-072fc7612376'></div>

# %% [markdown]
# ## Domain Augmentation from DeepPicar to DeepPicar-v2
#
# With the inital DAVE-2 model trained and giving good results, we will try it on the more relavent dataset to see if the angles are fairly close.

# %%
# Some constants for analyzing videos from DeepPicar-v2
N_FRAMES = 1000  # All avi files in DeepPicar-v2 are 1,000 frames
ORIG_IMG_HEIGHT = 240
ORIG_IMG_WIDTH = 320


# Define some helper functions
def key_from_video_filename(vf : str):
    directory_seperated = vf.split('\\')  # running on Windows
    fileno = int(directory_seperated[-1].split('-')[-1].split('.')[0])
    key_filename = 'out-key-%i.csv' % fileno
    return '\\'.join(directory_seperated[:-1] + [key_filename,])


def image_vector_from_video(vf : str, image_vector : np.ndarray):
    "Trying inplace"
    # Preallocate output
    # image_vector = np.empty((N_FRAMES, ORIG_IMG_HEIGHT, ORIG_IMG_WIDTH, 3))
    
    # Get the video vile into a video capture
    video_capture = cv2.VideoCapture(vf)
    
    # Loop through frames
    for i in range(N_FRAMES):
        _, image = video_capture.read()
        
        image_vector[i,:,:,:] = image  # Store image
        
        del image
    
    # Some resource freeing
    video_capture.release()
    del video_capture
    
    # return image_vector


# Grab video file list
dpv2_video_files = glob.glob("../data/external/DeepPicar-v2-data/*.avi")
N_VIDEOS = len(dpv2_video_files)
    
    
# Declare variables to images and angles
# dpv2_images = np.empty((N_VIDEOS*N_FRAMES, target_img_height, target_img_width, 3))  # MemoryError if N_VIDEOS*N_FRAMES
dpv2_angles = np.empty((N_VIDEOS*N_FRAMES,))
predicted_angles = np.empty((N_VIDEOS*N_FRAMES,))
dpv2_times = np.empty((N_VIDEOS*N_FRAMES,))

# Iterate through the avi files
for i, vf in enumerate(dpv2_video_files):
    # Load in csv of correct outputs
    temp = np.loadtxt(
        fname=key_from_video_filename(vf),
        delimiter=',',
        skiprows=1  # ignore the column titles
    )
    
    # assign correct outputs to arrays
    dpv2_times[i*N_FRAMES:(i+1)*N_FRAMES] = temp[:,0]/1e6  # converted microseconds to seconds
    dpv2_angles[i*N_FRAMES:(i+1)*N_FRAMES] = temp[:,2]  # In radians and in {-30deg, 0deg, 30deg}
    
    del temp
    
    # Grab images from video to do predictions on
    image_vec = np.empty((N_FRAMES, ORIG_IMG_HEIGHT, ORIG_IMG_WIDTH, 3))
    image_vector_from_video(vf, image_vec)
    # reshaped_image_vec = np.empty((image_vec.shape[0],) + (target_img_height, target_img_width,3))
    
    # Resize images to match DAVE-2, seems to break if 1000 images
    reshape_batch = 100
    for j in range(N_FRAMES//reshape_batch):
        temp = tf.image.resize(
            images=tf.convert_to_tensor(image_vec[j*reshape_batch:(j+1)*reshape_batch,:,:,:]),
            size=[target_img_height, target_img_width]
        ).numpy()
        
        # reshaped_image_vec[j*reshape_batch:(j+1)*reshape_batch] = temp
        
        # Do predictions
        # pred = dave_2_model.predict(x=reshaped_image_vec, verbose=(1 if i == 0 else 0))
        pred = dave_2_model.predict(x=temp, verbose=1)
        
        # Save predictions
        predicted_angles[
            (i*N_FRAMES + j*reshape_batch):(i*N_FRAMES + (j+1)*reshape_batch)
        ] = pred[:,0]
        
        del temp, pred
    
    # Outer loop cleanup
    del image_vec
# Out:
# 100/100 [==============================] - 0s 1ms/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 372us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 403us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 393us/sample
# 100/100 [==============================] - 0s 379us/sample
# 100/100 [==============================] - 0s 404us/sample
# 100/100 [==============================] - 0s 401us/sample
# 100/100 [==============================] - 0s 374us/sample
# 100/100 [==============================] - 0s 387us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 420us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 395us/sample
# 100/100 [==============================] - 0s 384us/sample
# 100/100 [==============================] - 0s 382us/sample
# 100/100 [==============================] - 0s 404us/sample
# 100/100 [==============================] - 0s 393us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 399us/sample
# 100/100 [==============================] - 0s 394us/sample
# 100/100 [==============================] - 0s 388us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 398us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 384us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 386us/sample
# 100/100 [==============================] - 0s 396us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 394us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 376us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 387us/sample
# 100/100 [==============================] - 0s 385us/sample
# 100/100 [==============================] - 0s 410us/sample
# 100/100 [==============================] - 0s 401us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 385us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 409us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 410us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 398us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 391us/sample
# 100/100 [==============================] - 0s 395us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 390us/sample

# %% [markdown]
# Having gone through all the DeepPicar-v2 and predicted the angle output from the neural network model trained on the DeepPicar dataset, it is now time to see the accuracy of the steering wheel angle.

# %%
# Rescale to {-1, 0, 1} for DeepPicar-v2
dpv2_angles = np.round(dpv2_angles*180./np.pi/30.)

# %%
# Also scale into {-1, 0, 1} with rounding
pred_control = np.round(predicted_angles)
pred_control[pred_control < -1] = -1
pred_control[pred_control > 1] = 1

# %%
cross_correlation_matrix = np.zeros((3,3))  # correlation matrix to see matches
for i in range(3):
    for j in range(3):
        cross_correlation_matrix[i, j] = np.count_nonzero(np.logical_and(
            np.equal(dpv2_angles, i-1),
            np.equal(pred_control, j-1),
        ))
        
"""
Quick note:
* column is predicted angle from -30 to 30 in left to right.
* row is actual from -30 to 30 from top to bottom.
"""
print(cross_correlation_matrix)

# Printing out the model statistics of discrete controller in the augmented domain
n_total = pred_control.shape[0]
n_correct = np.trace(cross_correlation_matrix)
n_incorrect = n_total - n_correct
print("Model accuracy: %2.2f%%'" % (100*n_correct/n_total))
# Out:
# [[ 757.  559.    0.]
#  [3043. 1417.    0.]
#  [3668. 1556.    0.]]
# Model accuracy: 19.76%'

# %% [markdown]
# So a couple of brief comments on the attempted domain augmentation is that the training dataset seems to have a large left turn bias while the augmented dataset has a larger right turn bias with less than 15% being a left turn example but around 50% being a right turn. The potential solution is to introduce some image augmentation into the DeepPicar to overcome left bias as well as some generic image manipulations like zoom or pan.
#
# ## Training with Image Augmentation
#
# Here is the list of image augmentiation that will be implemented to increase the dataset size:
#
# 1. Flip over image width.

# %%
# Preallocate new fitting inputs and output arrays
n_fit = x_fit.shape[0]
n_fit_aug = 2*n_fit
x_fit_aug = np.empty((n_fit_aug,) + x_fit.shape[1:])
y_fit_aug = np.empty((n_fit_aug,))

# Fill in original images and angles
x_fit_aug[:n_fit] = x_fit
y_fit_aug[:n_fit] = y_fit

# %%
# Add in the image flip
x_fit_aug[n_fit:2*n_fit] = x_fit[:,:,::-1,:]
y_fit_aug[n_fit:2*n_fit] = -y_fit

fig, ax = plt.subplots(1, 2)

ax[0].imshow(x_fit_aug[frame_num].astype(int))
ax[1].imshow(x_fit_aug[frame_num + n_fit].astype(int))

ax[0].set_title("Original")
ax[1].set_title("Horizontal Flip")

plt.show()
# Out:
# <div id='294e711d-98e2-45f7-86ac-c77eeb54c196'></div>

# %%
# Retrain a new Dave-2
dave_2_model = create_dave(x_fit_aug.shape[1:])
training_history = dave_2_model.fit(
    x=x_fit_aug, y=y_fit_aug,
    verbose=1,
    epochs=100,
    validation_split=0.2,
)
# Out:
# Train on 350 samples, validate on 88 samples
# Epoch 1/100
# 350/350 [==============================] - 1s 4ms/sample - loss: 0.2991 - mse: 0.2991 - val_loss: 0.6536 - val_mse: 0.6536
# Epoch 2/100
# 350/350 [==============================] - 0s 963us/sample - loss: 0.1100 - mse: 0.1100 - val_loss: 0.4542 - val_mse: 0.4542
# Epoch 3/100
# 350/350 [==============================] - 0s 946us/sample - loss: 0.0486 - mse: 0.0486 - val_loss: 0.4830 - val_mse: 0.4830
# Epoch 4/100
# 350/350 [==============================] - 0s 956us/sample - loss: 0.0322 - mse: 0.0322 - val_loss: 0.2836 - val_mse: 0.2836
# Epoch 5/100
# 350/350 [==============================] - 0s 964us/sample - loss: 0.0220 - mse: 0.0220 - val_loss: 0.2399 - val_mse: 0.2399
# Epoch 6/100
# 350/350 [==============================] - 0s 966us/sample - loss: 0.0196 - mse: 0.0196 - val_loss: 0.2012 - val_mse: 0.2012
# Epoch 7/100
# 350/350 [==============================] - 0s 961us/sample - loss: 0.0180 - mse: 0.0180 - val_loss: 0.1844 - val_mse: 0.1844
# Epoch 8/100
# 350/350 [==============================] - 0s 962us/sample - loss: 0.0155 - mse: 0.0155 - val_loss: 0.1405 - val_mse: 0.1405
# Epoch 9/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.1616 - val_mse: 0.1616
# Epoch 10/100
# 350/350 [==============================] - 0s 963us/sample - loss: 0.0102 - mse: 0.0102 - val_loss: 0.1777 - val_mse: 0.1777
# Epoch 11/100
# 350/350 [==============================] - 0s 960us/sample - loss: 0.0078 - mse: 0.0078 - val_loss: 0.1848 - val_mse: 0.1848
# Epoch 12/100
# 350/350 [==============================] - 0s 956us/sample - loss: 0.0096 - mse: 0.0096 - val_loss: 0.1857 - val_mse: 0.1857
# Epoch 13/100
# 350/350 [==============================] - 0s 989us/sample - loss: 0.0079 - mse: 0.0079 - val_loss: 0.2223 - val_mse: 0.2223
# Epoch 14/100
# 350/350 [==============================] - 0s 959us/sample - loss: 0.0083 - mse: 0.0083 - val_loss: 0.1878 - val_mse: 0.1878
# Epoch 15/100
# 350/350 [==============================] - 0s 957us/sample - loss: 0.0068 - mse: 0.0068 - val_loss: 0.1700 - val_mse: 0.1700
# Epoch 16/100
# 350/350 [==============================] - 0s 958us/sample - loss: 0.0062 - mse: 0.0062 - val_loss: 0.1665 - val_mse: 0.1665
# Epoch 17/100
# 350/350 [==============================] - 0s 961us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.1640 - val_mse: 0.1640
# Epoch 18/100
# 350/350 [==============================] - 0s 962us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.1490 - val_mse: 0.1490
# Epoch 19/100
# 350/350 [==============================] - 0s 965us/sample - loss: 0.0053 - mse: 0.0053 - val_loss: 0.1621 - val_mse: 0.1621
# Epoch 20/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0055 - mse: 0.0055 - val_loss: 0.1526 - val_mse: 0.1526
# Epoch 21/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0040 - mse: 0.0040 - val_loss: 0.1743 - val_mse: 0.1743
# Epoch 22/100
# 350/350 [==============================] - 0s 972us/sample - loss: 0.0033 - mse: 0.0033 - val_loss: 0.1603 - val_mse: 0.1603
# Epoch 23/100
# 350/350 [==============================] - 0s 964us/sample - loss: 0.0033 - mse: 0.0033 - val_loss: 0.1546 - val_mse: 0.1546
# Epoch 24/100
# 350/350 [==============================] - 0s 994us/sample - loss: 0.0041 - mse: 0.0041 - val_loss: 0.1558 - val_mse: 0.1558
# Epoch 25/100
# 350/350 [==============================] - 0s 972us/sample - loss: 0.0036 - mse: 0.0036 - val_loss: 0.1542 - val_mse: 0.1542
# Epoch 26/100
# 350/350 [==============================] - 0s 972us/sample - loss: 0.0046 - mse: 0.0046 - val_loss: 0.1525 - val_mse: 0.1525
# Epoch 27/100
# 350/350 [==============================] - 0s 967us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.1617 - val_mse: 0.1617
# Epoch 28/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0038 - mse: 0.0038 - val_loss: 0.1691 - val_mse: 0.1691
# Epoch 29/100
# 350/350 [==============================] - 0s 982us/sample - loss: 0.0034 - mse: 0.0034 - val_loss: 0.1661 - val_mse: 0.1661
# Epoch 30/100
# 350/350 [==============================] - 0s 959us/sample - loss: 0.0044 - mse: 0.0044 - val_loss: 0.1592 - val_mse: 0.1592
# Epoch 31/100
# 350/350 [==============================] - 0s 982us/sample - loss: 0.0042 - mse: 0.0042 - val_loss: 0.1536 - val_mse: 0.1536
# Epoch 32/100
# 350/350 [==============================] - 0s 965us/sample - loss: 0.0037 - mse: 0.0037 - val_loss: 0.1771 - val_mse: 0.1771
# Epoch 33/100
# 350/350 [==============================] - 0s 975us/sample - loss: 0.0028 - mse: 0.0028 - val_loss: 0.1761 - val_mse: 0.1761
# Epoch 34/100
# 350/350 [==============================] - 0s 971us/sample - loss: 0.0031 - mse: 0.0031 - val_loss: 0.1928 - val_mse: 0.1928
# Epoch 35/100
# 350/350 [==============================] - 0s 966us/sample - loss: 0.0025 - mse: 0.0025 - val_loss: 0.1626 - val_mse: 0.1626
# Epoch 36/100
# 350/350 [==============================] - 0s 958us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1936 - val_mse: 0.1936
# Epoch 37/100
# 350/350 [==============================] - 0s 969us/sample - loss: 0.0022 - mse: 0.0022 - val_loss: 0.1912 - val_mse: 0.1912
# Epoch 38/100
# 350/350 [==============================] - 0s 966us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.1766 - val_mse: 0.1766
# Epoch 39/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0021 - mse: 0.0021 - val_loss: 0.1967 - val_mse: 0.1967
# Epoch 40/100
# 350/350 [==============================] - 0s 970us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 41/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1814 - val_mse: 0.1814
# Epoch 42/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.2248 - val_mse: 0.2248
# Epoch 43/100
# 350/350 [==============================] - 0s 984us/sample - loss: 0.0017 - mse: 0.0017 - val_loss: 0.1735 - val_mse: 0.1735
# Epoch 44/100
# 350/350 [==============================] - 0s 970us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.1673 - val_mse: 0.1673
# Epoch 45/100
# 350/350 [==============================] - 0s 972us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1970 - val_mse: 0.1970
# Epoch 46/100
# 350/350 [==============================] - 0s 980us/sample - loss: 0.0024 - mse: 0.0024 - val_loss: 0.2168 - val_mse: 0.2168
# Epoch 47/100
# 350/350 [==============================] - 0s 989us/sample - loss: 0.0019 - mse: 0.0019 - val_loss: 0.1776 - val_mse: 0.1776
# Epoch 48/100
# 350/350 [==============================] - 0s 961us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1582 - val_mse: 0.1582
# Epoch 49/100
# 350/350 [==============================] - 0s 979us/sample - loss: 0.0013 - mse: 0.0013 - val_loss: 0.1630 - val_mse: 0.1630
# Epoch 50/100
# 350/350 [==============================] - 0s 974us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1891 - val_mse: 0.1891
# Epoch 51/100
# 350/350 [==============================] - 0s 977us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1733 - val_mse: 0.1733
# Epoch 52/100
# 350/350 [==============================] - 0s 977us/sample - loss: 0.0025 - mse: 0.0025 - val_loss: 0.1997 - val_mse: 0.1997
# Epoch 53/100
# 350/350 [==============================] - 0s 978us/sample - loss: 0.0022 - mse: 0.0022 - val_loss: 0.1632 - val_mse: 0.1632
# Epoch 54/100
# 350/350 [==============================] - 0s 964us/sample - loss: 0.0020 - mse: 0.0020 - val_loss: 0.1946 - val_mse: 0.1946
# Epoch 55/100
# 350/350 [==============================] - 0s 982us/sample - loss: 0.0015 - mse: 0.0015 - val_loss: 0.1911 - val_mse: 0.1911
# Epoch 56/100
# 350/350 [==============================] - 0s 971us/sample - loss: 0.0018 - mse: 0.0018 - val_loss: 0.1871 - val_mse: 0.1871
# Epoch 57/100
# 350/350 [==============================] - 0s 984us/sample - loss: 0.0014 - mse: 0.0014 - val_loss: 0.1697 - val_mse: 0.1697
# Epoch 58/100
# 350/350 [==============================] - 0s 976us/sample - loss: 0.0012 - mse: 0.0012 - val_loss: 0.1759 - val_mse: 0.1759
# Epoch 59/100
# 350/350 [==============================] - 0s 980us/sample - loss: 9.4633e-04 - mse: 9.4633e-04 - val_loss: 0.1816 - val_mse: 0.1816
# Epoch 60/100
# 350/350 [==============================] - 0s 967us/sample - loss: 8.3345e-04 - mse: 8.3345e-04 - val_loss: 0.1952 - val_mse: 0.1952
# Epoch 61/100
# 350/350 [==============================] - 0s 974us/sample - loss: 6.9950e-04 - mse: 6.9950e-04 - val_loss: 0.1857 - val_mse: 0.1857
# Epoch 62/100
# 350/350 [==============================] - 0s 988us/sample - loss: 6.3416e-04 - mse: 6.3416e-04 - val_loss: 0.1814 - val_mse: 0.1814
# Epoch 63/100
# 350/350 [==============================] - 0s 987us/sample - loss: 5.6943e-04 - mse: 5.6943e-04 - val_loss: 0.1811 - val_mse: 0.1811
# Epoch 64/100
# 350/350 [==============================] - 0s 982us/sample - loss: 4.3823e-04 - mse: 4.3823e-04 - val_loss: 0.1724 - val_mse: 0.1724
# Epoch 65/100
# 350/350 [==============================] - 0s 975us/sample - loss: 6.1497e-04 - mse: 6.1497e-04 - val_loss: 0.1704 - val_mse: 0.1704
# Epoch 66/100
# 350/350 [==============================] - 0s 992us/sample - loss: 6.3477e-04 - mse: 6.3477e-04 - val_loss: 0.1760 - val_mse: 0.1760
# Epoch 67/100
# 350/350 [==============================] - 0s 974us/sample - loss: 6.5277e-04 - mse: 6.5277e-04 - val_loss: 0.1618 - val_mse: 0.1618
# Epoch 68/100
# 350/350 [==============================] - 0s 968us/sample - loss: 8.1129e-04 - mse: 8.1129e-04 - val_loss: 0.1692 - val_mse: 0.1692
# Epoch 69/100
# 350/350 [==============================] - 0s 970us/sample - loss: 9.2049e-04 - mse: 9.2049e-04 - val_loss: 0.1614 - val_mse: 0.1614
# Epoch 70/100
# 350/350 [==============================] - 0s 965us/sample - loss: 8.7369e-04 - mse: 8.7369e-04 - val_loss: 0.1446 - val_mse: 0.1446
# Epoch 71/100
# 350/350 [==============================] - 0s 968us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.1502 - val_mse: 0.1502
# Epoch 72/100
# 350/350 [==============================] - 0s 983us/sample - loss: 0.0011 - mse: 0.0011 - val_loss: 0.1674 - val_mse: 0.1674
# Epoch 73/100
# 350/350 [==============================] - 0s 972us/sample - loss: 8.3406e-04 - mse: 8.3406e-04 - val_loss: 0.1799 - val_mse: 0.1799
# Epoch 74/100
# 350/350 [==============================] - 0s 984us/sample - loss: 0.0010 - mse: 0.0010 - val_loss: 0.1682 - val_mse: 0.1682
# Epoch 75/100
# 350/350 [==============================] - 0s 982us/sample - loss: 5.3649e-04 - mse: 5.3649e-04 - val_loss: 0.1873 - val_mse: 0.1873
# Epoch 76/100
# 350/350 [==============================] - 0s 971us/sample - loss: 6.5455e-04 - mse: 6.5455e-04 - val_loss: 0.1665 - val_mse: 0.1665
# Epoch 77/100
# 350/350 [==============================] - 0s 977us/sample - loss: 6.7456e-04 - mse: 6.7456e-04 - val_loss: 0.1662 - val_mse: 0.1662
# Epoch 78/100
# 350/350 [==============================] - 0s 1ms/sample - loss: 6.8938e-04 - mse: 6.8938e-04 - val_loss: 0.1553 - val_mse: 0.1553
# Epoch 79/100
# 350/350 [==============================] - 0s 976us/sample - loss: 5.1371e-04 - mse: 5.1371e-04 - val_loss: 0.1539 - val_mse: 0.1539
# Epoch 80/100
# 350/350 [==============================] - 0s 974us/sample - loss: 3.9621e-04 - mse: 3.9621e-04 - val_loss: 0.1659 - val_mse: 0.1659
# Epoch 81/100
# 350/350 [==============================] - 0s 992us/sample - loss: 4.4490e-04 - mse: 4.4490e-04 - val_loss: 0.1577 - val_mse: 0.1577
# Epoch 82/100
# 350/350 [==============================] - 0s 975us/sample - loss: 5.3927e-04 - mse: 5.3927e-04 - val_loss: 0.1628 - val_mse: 0.1628
# Epoch 83/100
# 350/350 [==============================] - 0s 980us/sample - loss: 4.5407e-04 - mse: 4.5407e-04 - val_loss: 0.1586 - val_mse: 0.1586
# Epoch 84/100
# 350/350 [==============================] - 0s 986us/sample - loss: 4.2484e-04 - mse: 4.2484e-04 - val_loss: 0.1654 - val_mse: 0.1654
# Epoch 85/100
# 350/350 [==============================] - 0s 980us/sample - loss: 3.9053e-04 - mse: 3.9053e-04 - val_loss: 0.1646 - val_mse: 0.1646
# Epoch 86/100
# 350/350 [==============================] - 0s 967us/sample - loss: 4.5421e-04 - mse: 4.5421e-04 - val_loss: 0.1777 - val_mse: 0.1777
# Epoch 87/100
# 350/350 [==============================] - 0s 982us/sample - loss: 6.9922e-04 - mse: 6.9922e-04 - val_loss: 0.1712 - val_mse: 0.1712
# Epoch 88/100
# 350/350 [==============================] - 0s 977us/sample - loss: 9.1202e-04 - mse: 9.1202e-04 - val_loss: 0.1712 - val_mse: 0.1712
# Epoch 89/100
# 350/350 [==============================] - 0s 971us/sample - loss: 8.3219e-04 - mse: 8.3219e-04 - val_loss: 0.1511 - val_mse: 0.1511
# Epoch 90/100
# 350/350 [==============================] - 0s 971us/sample - loss: 9.1078e-04 - mse: 9.1078e-04 - val_loss: 0.1600 - val_mse: 0.1600
# Epoch 91/100
# 350/350 [==============================] - 0s 985us/sample - loss: 7.7248e-04 - mse: 7.7248e-04 - val_loss: 0.1732 - val_mse: 0.1732
# Epoch 92/100
# 350/350 [==============================] - 0s 979us/sample - loss: 5.9738e-04 - mse: 5.9738e-04 - val_loss: 0.1520 - val_mse: 0.1520
# Epoch 93/100
# 350/350 [==============================] - 0s 1ms/sample - loss: 5.4346e-04 - mse: 5.4346e-04 - val_loss: 0.1597 - val_mse: 0.1597
# Epoch 94/100
# 350/350 [==============================] - 0s 972us/sample - loss: 4.4042e-04 - mse: 4.4042e-04 - val_loss: 0.1394 - val_mse: 0.1394
# Epoch 95/100
# 350/350 [==============================] - 0s 988us/sample - loss: 5.0591e-04 - mse: 5.0591e-04 - val_loss: 0.1431 - val_mse: 0.1431
# Epoch 96/100
# 350/350 [==============================] - 0s 986us/sample - loss: 3.6571e-04 - mse: 3.6571e-04 - val_loss: 0.1572 - val_mse: 0.1572
# Epoch 97/100
# 350/350 [==============================] - 0s 976us/sample - loss: 3.6949e-04 - mse: 3.6949e-04 - val_loss: 0.1517 - val_mse: 0.1517
# Epoch 98/100
# 350/350 [==============================] - 0s 984us/sample - loss: 3.6386e-04 - mse: 3.6386e-04 - val_loss: 0.1617 - val_mse: 0.1617
# Epoch 99/100
# 350/350 [==============================] - 0s 985us/sample - loss: 5.7088e-04 - mse: 5.7088e-04 - val_loss: 0.1471 - val_mse: 0.1471
# Epoch 100/100
# 350/350 [==============================] - 0s 950us/sample - loss: 6.1108e-04 - mse: 6.1108e-04 - val_loss: 0.1502 - val_mse: 0.1502

# %%
loss_vec = np.array(training_history.history['loss'])
val_loss_vec = np.array(training_history.history['val_loss'])

epoch_vec = np.arange(loss_vec.shape[0]) + 1

fig, ax = plt.subplots(1, 1)

ax.plot(epoch_vec, loss_vec, color='C0', label="Training Loss")
ax.plot(epoch_vec, val_loss_vec, color='C1', label="Validation Loss")

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)

ax.set_xlabel("Training Epoch")
ax.set_ylabel("Mean Square Error")

ax.legend()

plt.show()
# Out:
# <div id='b785b955-8dfc-4aa9-915a-2a92c25042ad'></div>

# %%
# Iterate through the DeepPicar-v2 to redo prediction angles    
for i, vf in enumerate(dpv2_video_files):   
    # Grab images from video to do predictions on
    image_vec = np.empty((N_FRAMES, ORIG_IMG_HEIGHT, ORIG_IMG_WIDTH, 3))
    image_vector_from_video(vf, image_vec)
    
    # Resize images to match DAVE-2, seems to break if 1000 images
    reshape_batch = 100
    for j in range(N_FRAMES//reshape_batch):
        temp = tf.image.resize(
            images=tf.convert_to_tensor(image_vec[j*reshape_batch:(j+1)*reshape_batch,:,:,:]),
            size=[target_img_height, target_img_width]
        ).numpy()
        
        # reshaped_image_vec[j*reshape_batch:(j+1)*reshape_batch] = temp
        
        # Do predictions
        pred = dave_2_model.predict(x=temp, verbose=1)
        
        # Save predictions
        predicted_angles[
            (i*N_FRAMES + j*reshape_batch):(i*N_FRAMES + (j+1)*reshape_batch)
        ] = pred[:,0]
        
        del temp, pred
    
    # Outer loop cleanup
    del image_vec
# Out:
# 100/100 [==============================] - 0s 1ms/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 396us/sample
# 100/100 [==============================] - 0s 378us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 391us/sample
# 100/100 [==============================] - 0s 392us/sample
# 100/100 [==============================] - 0s 384us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 395us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 386us/sample
# 100/100 [==============================] - 0s 387us/sample
# 100/100 [==============================] - 0s 404us/sample
# 100/100 [==============================] - 0s 395us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 387us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 374us/sample
# 100/100 [==============================] - 0s 436us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 378us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 393us/sample
# 100/100 [==============================] - 0s 420us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 402us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 387us/sample
# 100/100 [==============================] - 0s 382us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 379us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 398us/sample
# 100/100 [==============================] - 0s 378us/sample
# 100/100 [==============================] - 0s 401us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 385us/sample
# 100/100 [==============================] - 0s 396us/sample
# 100/100 [==============================] - 0s 394us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 389us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 383us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 369us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 365us/sample
# 100/100 [==============================] - 0s 410us/sample
# 100/100 [==============================] - 0s 394us/sample
# 100/100 [==============================] - 0s 381us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 370us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 400us/sample
# 100/100 [==============================] - 0s 390us/sample
# 100/100 [==============================] - 0s 380us/sample
# 100/100 [==============================] - 0s 397us/sample
# 100/100 [==============================] - 0s 380us/sample

# %%
pred_control = np.round(predicted_angles)
pred_control[pred_control < -1] = -1
pred_control[pred_control > 1] = 1

cross_correlation_matrix = np.zeros((3,3))  # correlation matrix to see matches
for i in range(3):
    for j in range(3):
        cross_correlation_matrix[i, j] = np.count_nonzero(np.logical_and(
            np.equal(dpv2_angles, i-1),
            np.equal(pred_control, j-1),
        ))
        
"""
Quick note:
* column is predicted angle from -30 to 30 in left to right.
* row is actual from -30 to 30 from top to bottom.
"""
print(cross_correlation_matrix)

# Printing out the model statistics of discrete controller in the augmented domain
n_total = pred_control.shape[0]
n_correct = np.trace(cross_correlation_matrix)
n_incorrect = n_total - n_correct
print("Model accuracy: %2.2f%%'" % (100*n_correct/n_total))
# Out:
# [[4.000e+01 1.275e+03 1.000e+00]
#  [1.560e+02 4.298e+03 6.000e+00]
#  [1.640e+02 5.036e+03 2.400e+01]]
# Model accuracy: 39.65%'

# %% [markdown]
# The accuracy of the model has dramatically improved but stil need to verify the quality. It is unsure whether the wheel angles are an accurate representation.

# %%
# Iterate through the DeepPicar-v2 to make a video for quality analysis



for i, vf in enumerate(dpv2_video_files): 
    cap = cv2.VideoCapture(vf)
    j = 0
    while(cap.isOpened() and j < N_FRAMES):
        
        ret, frame = cap.read()
        
        # Show the frame of video
        img = cv2.imshow('frame',frame)
        
        # Plot on the frame
        cv2.line(img, (0,0), (60, 200), (255,)*3, 15)
        
        
        j += 1  # Increment a counter
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-ddd16bf292b5> in <module>
#      11
#      12         # Show the frame of video
# ---> 13         img = cv2.imshow('frame',frame)
#      14
#      15         # Plot on the frame
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-oduouqig\opencv\modules\highgui\src\window.cpp:376: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

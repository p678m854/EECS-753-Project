# %% [markdown]
# # Initial Exploration
#
# This project is based on the original [DeepPiCar](https://github.com/dctian/DeepPiCar) project which simply uses a Raspberry Pi with a camera on a simple radio controlled car. A vary similiar project [DeepPicar-v2](https://github.com/mbechtel2/DeepPicar-v2) done by members of University of Kansas. The DeepPiCar has data as well as the angles embedded in the images while DeepPicar-v2 has modulated the angles to $\lbrace -30, 0, +30\rbrace$ degrees on its outputs. Both are using the convolutional neural network architecture of the [DAVE-2](https://developer.nvidia.com/blog/deep-learning-self-driving-cars/) so for now training will only be done on the DeepPiCar data and comparison with their model.
#
# ## Camera Inputs
#
# This section will look at the images being supplied by the DeepPiCar project as well as some image distortions achievable. First thing is to import the required libraries.

# %%
from cv2 import cv2              # an open computer vision module
import glob                      # Regix searching of files
import imageio                   # loading images in numpy array
import matplotlib.pyplot as plt  # Plotting
# %matplotlib notebook
import numpy as np               # Array/Tensors
import os                        # finding paths
import pandas as pd              # Dataframe for viewing
import PIL                       # Python Imaging Library
import sys                       # manipulating the path variable
import tensorflow as tf          # Neural Networks

# %% [markdown]
# With these modules imported add in the location of the training images as well as the location of the DeepPiCar neural network.

# %%
sys.path.append(os.path.abspath('../data/external/'))
sys.path.append(os.path.abspath('../models/'))

# %% [markdown]
# With the added locations we can look load the data into a numpy data frame as well as a numpy array of angles.

# %%
# See number of images
image_list = glob.glob("../data/external/DeepPicar-data/*.png")  # All images

N = len(image_list)

image_vec = None  # Input
index_vec = np.empty((N,), dtype=np.int32) # Index
angle_vec = np.empty((N,), dtype=np.float64)  # Output Target

for i, f in enumerate(image_list):
    # Read in file
    image = imageio.imread(f)
    index = int(f.split('_')[-2])  # Frame index
    angle = float(f.split('_')[-1].split('.')[0])  # in degrees
    
    # Create image storage if necessary
    if image_vec is None:
        image_vec = np.empty((N,) + image.shape, dtype=np.float64)
    
    # Store file information
    image_vec[i] = image
    index_vec[i] = index
    angle_vec[i] = angle
    
# Some constants for resizing
target_img_height = 66
target_img_width = 200

# Resize the images
print("Original image vector dimensions: %s" % str(image_vec.shape))

image_vec = tf.image.resize(  # Maybe replace in network with crop
    images=tf.convert_to_tensor(image_vec),
    size=[target_img_height, target_img_width]
).numpy()

print("New image vector dimensions: %s" % str(image_vec.shape))
# Out:
# Original image vector dimensions: (219, 240, 320, 3)
# New image vector dimensions: (219, 66, 200, 3)

# %% [markdown]
# ## Model Building
#
# With the images loaded and reshaped to the DAVE-2 image size we create a DAVE-2 neural network model for initial comparison work.

# %%
# Create tensorflow object
dave_2_model = tf.keras.Sequential()

# First is a normalization layer in DAVE-2 but I don't see it in DeepPicar-v2 model-5conv_3fc
# Attempting to normalize over color
dave_2_model.add(tf.keras.layers.LayerNormalization(
    axis=[1, 2, 3], trainable=False,
    input_shape=image_vec.shape[1:]  # Specify ahead of time for compilation
))

"""
Brief comment:
* Both DeepPicar and DeepPicar-v2 use a 240x320 frame initially but DeepPicar-v2 reshapes=66x200
* DAVE-2 uses 66x200
* Either I need to downsample both or I just ignore it since the DeepPicar's match.
* Going with matching. <- scratch, will match dimensions
"""

# Second portion is the sequential 5x5 convolutions of increasing filters at 2x2 strides
for i in range(3):
    dave_2_model.add(tf.keras.layers.Conv2D(
        filters=(24 + i*12),
        kernel_size=(5,5),
        strides=(2,2),
        padding='valid',
        data_format='channels_last',
        activation=tf.nn.relu
    ))

# Third there is another grouping of Conv2D layers but a 3x3 kernel with no stride
for i in range(2):
    dave_2_model.add(tf.keras.layers.Conv2D(
        filters=64,
        kernel_size=(3,3),
        padding='valid',
        data_format='channels_last',
        activation=tf.nn.relu
    ))

# Fourth and final part is a flattening and then reduction to a single output
dave_2_model.add(tf.keras.layers.Flatten())
for n_neurons in [100, 50, 10, 1]:
    dave_2_model.add(tf.keras.layers.Dense(
        units=n_neurons,
        activation=(tf.nn.tanh if n_neurons == 1 else tf.nn.relu)
    ))

# Compiling the model to see the initial structure
dave_2_model.compile(
    optimizer='adam',
    loss=['mse'],
    metrics=['mse']
)

dave_2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_normalization (LayerNo (None, 66, 200, 3)        79200
# _________________________________________________________________
# conv2d (Conv2D)              (None, 31, 98, 24)        1824
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 47, 36)        21636
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 22, 48)         43248
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 20, 64)         27712
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 18, 64)         36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               115300
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 331,419
# Trainable params: 252,219
# Non-trainable params: 79,200
# _________________________________________________________________

# %% [markdown]
# ## Model Training on DeepPicar
#
# With the model compiled and built initially, we will train on the DeepPicar Dataset and then see the accuraccy against the DeepPicar-v2 dataset

# %%
y_fit = (angle_vec - 90.)/30.

training_history = dave_2_model.fit(
    x=image_vec, y=y_fit,
    verbose=1,
    epochs=100,
    validation_split=0.2,
)
# Out:
# Train on 175 samples, validate on 44 samples
# Epoch 1/100
# 175/175 [==============================] - 2s 13ms/sample - loss: 0.2753 - mse: 0.2753 - val_loss: 0.0301 - val_mse: 0.0301
# Epoch 2/100
# 175/175 [==============================] - 0s 913us/sample - loss: 0.1141 - mse: 0.1141 - val_loss: 0.0598 - val_mse: 0.0598
# Epoch 3/100
# 175/175 [==============================] - 0s 890us/sample - loss: 0.0820 - mse: 0.0820 - val_loss: 0.0796 - val_mse: 0.0796
# Epoch 4/100
# 175/175 [==============================] - 0s 898us/sample - loss: 0.0732 - mse: 0.0732 - val_loss: 0.0781 - val_mse: 0.0781
# Epoch 5/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0656 - mse: 0.0656 - val_loss: 0.0692 - val_mse: 0.0692
# Epoch 6/100
# 175/175 [==============================] - 0s 914us/sample - loss: 0.0592 - mse: 0.0592 - val_loss: 0.0866 - val_mse: 0.0866
# Epoch 7/100
# 175/175 [==============================] - 0s 885us/sample - loss: 0.0556 - mse: 0.0556 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 8/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0529 - mse: 0.0529 - val_loss: 0.0977 - val_mse: 0.0977
# Epoch 9/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0503 - mse: 0.0503 - val_loss: 0.0821 - val_mse: 0.0821
# Epoch 10/100
# 175/175 [==============================] - 0s 914us/sample - loss: 0.0478 - mse: 0.0478 - val_loss: 0.0997 - val_mse: 0.0997
# Epoch 11/100
# 175/175 [==============================] - 0s 919us/sample - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0814 - val_mse: 0.0814
# Epoch 12/100
# 175/175 [==============================] - 0s 914us/sample - loss: 0.0381 - mse: 0.0381 - val_loss: 0.1127 - val_mse: 0.1127
# Epoch 13/100
# 175/175 [==============================] - 0s 895us/sample - loss: 0.0359 - mse: 0.0359 - val_loss: 0.0944 - val_mse: 0.0944
# Epoch 14/100
# 175/175 [==============================] - 0s 901us/sample - loss: 0.0311 - mse: 0.0311 - val_loss: 0.0891 - val_mse: 0.0891
# Epoch 15/100
# 175/175 [==============================] - 0s 913us/sample - loss: 0.0312 - mse: 0.0312 - val_loss: 0.1738 - val_mse: 0.1738
# Epoch 16/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0386 - mse: 0.0386 - val_loss: 0.1245 - val_mse: 0.1245
# Epoch 17/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0320 - mse: 0.0320 - val_loss: 0.0988 - val_mse: 0.0988
# Epoch 18/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0306 - mse: 0.0306 - val_loss: 0.1034 - val_mse: 0.1034
# Epoch 19/100
# 175/175 [==============================] - 0s 954us/sample - loss: 0.0280 - mse: 0.0280 - val_loss: 0.1125 - val_mse: 0.1125
# Epoch 20/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0208 - mse: 0.0208 - val_loss: 0.1189 - val_mse: 0.1189
# Epoch 21/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0269 - mse: 0.0269 - val_loss: 0.1005 - val_mse: 0.1005
# Epoch 22/100
# 175/175 [==============================] - 0s 892us/sample - loss: 0.0224 - mse: 0.0224 - val_loss: 0.0801 - val_mse: 0.0801
# Epoch 23/100
# 175/175 [==============================] - 0s 904us/sample - loss: 0.0201 - mse: 0.0201 - val_loss: 0.0789 - val_mse: 0.0789
# Epoch 24/100
# 175/175 [==============================] - 0s 899us/sample - loss: 0.0175 - mse: 0.0175 - val_loss: 0.0832 - val_mse: 0.0832
# Epoch 25/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0848 - val_mse: 0.0848
# Epoch 26/100
# 175/175 [==============================] - 0s 912us/sample - loss: 0.0160 - mse: 0.0160 - val_loss: 0.1041 - val_mse: 0.1041
# Epoch 27/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0161 - mse: 0.0161 - val_loss: 0.0804 - val_mse: 0.0804
# Epoch 28/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0159 - mse: 0.0159 - val_loss: 0.0903 - val_mse: 0.0903
# Epoch 29/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0996 - val_mse: 0.0996
# Epoch 30/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0149 - mse: 0.0149 - val_loss: 0.0744 - val_mse: 0.0744
# Epoch 31/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0964 - val_mse: 0.0964
# Epoch 32/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0962 - val_mse: 0.0962
# Epoch 33/100
# 175/175 [==============================] - 0s 911us/sample - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 34/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0144 - mse: 0.0144 - val_loss: 0.0846 - val_mse: 0.0846
# Epoch 35/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 36/100
# 175/175 [==============================] - 0s 909us/sample - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0993 - val_mse: 0.0993
# Epoch 37/100
# 175/175 [==============================] - 0s 991us/sample - loss: 0.0149 - mse: 0.0149 - val_loss: 0.1086 - val_mse: 0.1086
# Epoch 38/100
# 175/175 [==============================] - 0s 912us/sample - loss: 0.0151 - mse: 0.0151 - val_loss: 0.0844 - val_mse: 0.0844
# Epoch 39/100
# 175/175 [==============================] - 0s 905us/sample - loss: 0.0147 - mse: 0.0147 - val_loss: 0.0807 - val_mse: 0.0807
# Epoch 40/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0828 - val_mse: 0.0828
# Epoch 41/100
# 175/175 [==============================] - 0s 901us/sample - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 42/100
# 175/175 [==============================] - 0s 904us/sample - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0787 - val_mse: 0.0787
# Epoch 43/100
# 175/175 [==============================] - 0s 918us/sample - loss: 0.0138 - mse: 0.0138 - val_loss: 0.1042 - val_mse: 0.1042
# Epoch 44/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0152 - mse: 0.0152 - val_loss: 0.0699 - val_mse: 0.0699
# Epoch 45/100
# 175/175 [==============================] - 0s 914us/sample - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0969 - val_mse: 0.0969
# Epoch 46/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 47/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0958 - val_mse: 0.0958
# Epoch 48/100
# 175/175 [==============================] - 0s 897us/sample - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0747 - val_mse: 0.0747
# Epoch 49/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 50/100
# 175/175 [==============================] - 0s 900us/sample - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0806 - val_mse: 0.0806
# Epoch 51/100
# 175/175 [==============================] - 0s 894us/sample - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0810 - val_mse: 0.0810
# Epoch 52/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0137 - mse: 0.0137 - val_loss: 0.1119 - val_mse: 0.1119
# Epoch 53/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0138 - mse: 0.0138 - val_loss: 0.0825 - val_mse: 0.0825
# Epoch 54/100
# 175/175 [==============================] - 0s 884us/sample - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0859 - val_mse: 0.0859
# Epoch 55/100
# 175/175 [==============================] - 0s 880us/sample - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 56/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0850 - val_mse: 0.0850
# Epoch 57/100
# 175/175 [==============================] - 0s 889us/sample - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0865 - val_mse: 0.0865
# Epoch 58/100
# 175/175 [==============================] - 0s 882us/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 0.1024 - val_mse: 0.1024
# Epoch 59/100
# 175/175 [==============================] - 0s 893us/sample - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0774 - val_mse: 0.0774
# Epoch 60/100
# 175/175 [==============================] - 0s 884us/sample - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0744 - val_mse: 0.0744
# Epoch 61/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0869 - val_mse: 0.0869
# Epoch 62/100
# 175/175 [==============================] - 0s 909us/sample - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 63/100
# 175/175 [==============================] - 0s 894us/sample - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0788 - val_mse: 0.0788
# Epoch 64/100
# 175/175 [==============================] - 0s 899us/sample - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0766 - val_mse: 0.0766
# Epoch 65/100
# 175/175 [==============================] - 0s 908us/sample - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0888 - val_mse: 0.0888
# Epoch 66/100
# 175/175 [==============================] - 0s 916us/sample - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0861 - val_mse: 0.0861
# Epoch 67/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0779 - val_mse: 0.0779
# Epoch 68/100
# 175/175 [==============================] - 0s 899us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0797 - val_mse: 0.0797
# Epoch 69/100
# 175/175 [==============================] - 0s 900us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0813 - val_mse: 0.0813
# Epoch 70/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0919 - val_mse: 0.0919
# Epoch 71/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0842 - val_mse: 0.0842
# Epoch 72/100
# 175/175 [==============================] - 0s 906us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0779 - val_mse: 0.0779
# Epoch 73/100
# 175/175 [==============================] - 0s 899us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 74/100
# 175/175 [==============================] - 0s 892us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0872 - val_mse: 0.0872
# Epoch 75/100
# 175/175 [==============================] - 0s 885us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0779 - val_mse: 0.0779
# Epoch 76/100
# 175/175 [==============================] - 0s 895us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0771 - val_mse: 0.0771
# Epoch 77/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0812 - val_mse: 0.0812
# Epoch 78/100
# 175/175 [==============================] - 0s 892us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0844 - val_mse: 0.0844
# Epoch 79/100
# 175/175 [==============================] - 0s 890us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0843 - val_mse: 0.0843
# Epoch 80/100
# 175/175 [==============================] - 0s 903us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0830 - val_mse: 0.0830
# Epoch 81/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0804 - val_mse: 0.0804
# Epoch 82/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0833 - val_mse: 0.0833
# Epoch 83/100
# 175/175 [==============================] - 0s 882us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0874 - val_mse: 0.0874
# Epoch 84/100
# 175/175 [==============================] - 0s 893us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0907 - val_mse: 0.0907
# Epoch 85/100
# 175/175 [==============================] - 0s 886us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 86/100
# 175/175 [==============================] - 0s 894us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0723 - val_mse: 0.0723
# Epoch 87/100
# 175/175 [==============================] - 0s 906us/sample - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0837 - val_mse: 0.0837
# Epoch 88/100
# 175/175 [==============================] - 0s 901us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0855 - val_mse: 0.0855
# Epoch 89/100
# 175/175 [==============================] - 0s 905us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0741 - val_mse: 0.0741
# Epoch 90/100
# 175/175 [==============================] - 0s 902us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0886 - val_mse: 0.0886
# Epoch 91/100
# 175/175 [==============================] - 0s 891us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0730 - val_mse: 0.0730
# Epoch 92/100
# 175/175 [==============================] - 0s 889us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0875 - val_mse: 0.0875
# Epoch 93/100
# 175/175 [==============================] - 0s 904us/sample - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0853 - val_mse: 0.0853
# Epoch 94/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0871 - val_mse: 0.0871
# Epoch 95/100
# 175/175 [==============================] - 0s 899us/sample - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0855 - val_mse: 0.0855
# Epoch 96/100
# 175/175 [==============================] - 0s 893us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0874 - val_mse: 0.0874
# Epoch 97/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0838 - val_mse: 0.0838
# Epoch 98/100
# 175/175 [==============================] - 0s 907us/sample - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0824 - val_mse: 0.0824
# Epoch 99/100
# 175/175 [==============================] - 0s 896us/sample - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0829 - val_mse: 0.0829
# Epoch 100/100
# 175/175 [==============================] - 0s 878us/sample - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0854 - val_mse: 0.0854

# %% [markdown]
# After training doing some plotting to see the training history results.

# %%
loss_vec = np.array(training_history.history['loss'])
val_loss_vec = np.array(training_history.history['val_loss'])

epoch_vec = np.arange(loss_vec.shape[0]) + 1

fig, ax = plt.subplots(1, 1)

ax.plot(epoch_vec, loss_vec, color='C0', label="Training Loss")
ax.plot(epoch_vec, val_loss_vec, color='C1', label="Validation Loss")

ax.set_xlim(left=0)
ax.set_ylim(bottom=0)

ax.set_xlabel("Training Epoch")
ax.set_ylabel("Mean Square Error")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# The training looks fine, maybe optimal epoch number is 50 epochs. Let us check visually to make sure the results look reasonable.

# %%
# Constant
frame_num = 130

x_base = 100
y_base = 60
radius = 20

p_angle = (30*dave_2_model.predict(image_vec)[frame_num] + 90)/180*np.pi
t_angle = angle_vec[frame_num]/180*np.pi

fig, ax = plt.subplots(1, 1)

ax.imshow(image_vec[frame_num].astype(int))
ax.plot(  # Arrow might be better
    np.array([x_base, x_base + radius*np.cos(np.pi - p_angle)]),
    np.array([y_base, y_base - radius*np.sin(p_angle)]),
    linewidth=5,
    label=("Predicted Angle (%.1f)" % (180./np.pi*p_angle))
)

ax.plot(  # Arrow might be better
    np.array([x_base, x_base + radius*np.cos(np.pi - t_angle)]),
    np.array([y_base, y_base - radius*np.sin(t_angle)]),
    linewidth=5,
    color='C3',
    label=("Target Angle (%.1f)" % (180./np.pi*t_angle))
)

ax.set_title("Frame %i" % frame_num)
ax.set_xlabel("Pixel Width")
ax.set_ylabel("Pixel Height")
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## Domain Augmentation from DeepPicar to DeepPicar-v2
#
# With the inital DAVE-2 model trained and giving good results, we will try it on the more relavent dataset to see if the angles are fairly close.

# %%
dpv2_video_files = glob.glob("../data/external/DeepPicar-v2-data/*.avi")
N_FRAMES = 1000  # All avi files in DeepPicar-v2 are 1,000 frames

# Iterate through the avi files
for vf in dpv2_video_files:
    # Get the video vile into a video capture
    video_capture = cv2.VideoCapture(vf)
    
    # Preallocate numpy array to hold frames
    augment_data = np.empty((N_FRAMES, ), dtype=np.int64)
    
    # Loop through frames
    for _ in range(N_FRAMES):
        _, image = video_capture.read()
    
    video_capture.release()
# Out:
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
